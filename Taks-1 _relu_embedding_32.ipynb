# %% [markdown]
# Importing data from file

# %% [markdown]
# #importing data
# import pandas as p

# %%
import re
# read file
text = open('dataset-1.txt', 'r', encoding='utf-8').read()
text = text.replace('\r\n', '\n').replace('\r', '\n')
# text = re.sub(r'(\n\s*\n)+', ' . . . . . ', text) # replace multiple newlines with ' . . . . . '
text = re.sub(r'[-]+', ' ', text) # replace hyphens with space
text = re.sub(r'[^a-zA-Z0-9 \.\n]', '', text) # remove special characters except period
text = re.sub(r'\n\n', ' <EOS> ', text) # replace newlines with space
text = re.sub(r'\.+', '.', text).strip() # collapse multiple spaces into one
text = re.sub(r'\.', ' . ', text) # surround periods with spaces
text = re.sub(r'\s+', ' ', text).strip() # collapse multiple spaces into one
text = text.lower() # convert to lowercase

# %%
window_size = 4

paragraphs = text.split(' <eos> ')
# words = [word for para in paragraphs for word in para.split() + ['<EOS>']]
words = []
for para in paragraphs:
    words.extend(para.split(' ') + ['<PAD>'] * window_size)

# %%
X, Y = [], []
for i in range(len(words)):
    start_idx = max(0, i - window_size)
    context = words[start_idx:i]
    context = ['<PAD>'] * (window_size - len(context)) + context  # left padding
    target = words[i]

    X.append(context)
    Y.append(target)


for i in range(100):
    print(' '.join(X[i]), '--->', Y[i])
# Out:
# <PAD> <PAD> <PAD> <PAD> ---> well
# <PAD> <PAD> <PAD> well ---> prince
# <PAD> <PAD> well prince ---> so
# <PAD> well prince so ---> genoa
# well prince so genoa ---> and
# prince so genoa and ---> lucca
# so genoa and lucca ---> are
# genoa and lucca are ---> now
# and lucca are now ---> just
# lucca are now just ---> family
# are now just family ---> estates
# now just family estates ---> of
# just family estates of ---> the
# family estates of the ---> buonapartes
# estates of the buonapartes ---> .
# of the buonapartes . ---> but
# the buonapartes . but ---> i
# buonapartes . but i ---> warn
# . but i warn ---> you
# but i warn you ---> if
# i warn you if ---> you
# warn you if you ---> dont
# you if you dont ---> tell
# if you dont tell ---> me
# you dont tell me ---> that
# dont tell me that ---> this
# tell me that this ---> means
# me that this means ---> war
# that this means war ---> if
# this means war if ---> you
# means war if you ---> still
# war if you still ---> try
# if you still try ---> to
# you still try to ---> defend
# still try to defend ---> the
# try to defend the ---> infamies
# to defend the infamies ---> and
# defend the infamies and ---> horrors
# the infamies and horrors ---> perpetrated
# infamies and horrors perpetrated ---> by
# and horrors perpetrated by ---> that
# horrors perpetrated by that ---> antichrist
# perpetrated by that antichrist ---> i
# by that antichrist i ---> really
# that antichrist i really ---> believe
# antichrist i really believe ---> he
# i really believe he ---> is
# really believe he is ---> antichrist
# believe he is antichrist ---> i
# he is antichrist i ---> will
# is antichrist i will ---> have
# antichrist i will have ---> nothing
# i will have nothing ---> more
# will have nothing more ---> to
# have nothing more to ---> do
# nothing more to do ---> with
# more to do with ---> you
# to do with you ---> and
# do with you and ---> you
# with you and you ---> are
# you and you are ---> no
# and you are no ---> longer
# you are no longer ---> my
# are no longer my ---> friend
# no longer my friend ---> no
# longer my friend no ---> longer
# my friend no longer ---> my
# friend no longer my ---> faithful
# no longer my faithful ---> slave
# longer my faithful slave ---> as
# my faithful slave as ---> you
# faithful slave as you ---> call
# slave as you call ---> yourself
# as you call yourself ---> but
# you call yourself but ---> how
# call yourself but how ---> do
# yourself but how do ---> you
# but how do you ---> do
# how do you do ---> i
# do you do i ---> see
# you do i see ---> i
# do i see i ---> have
# i see i have ---> frightened
# see i have frightened ---> you
# i have frightened you ---> sit
# have frightened you sit ---> down
# frightened you sit down ---> and
# you sit down and ---> tell
# sit down and tell ---> me
# down and tell me ---> all
# and tell me all ---> the
# tell me all the ---> news
# me all the news ---> .
# all the news . ---> <PAD>
# the news . <PAD> ---> <PAD>
# news . <PAD> <PAD> ---> <PAD>
# . <PAD> <PAD> <PAD> ---> <PAD>
# <PAD> <PAD> <PAD> <PAD> ---> it
# <PAD> <PAD> <PAD> it ---> was
# <PAD> <PAD> it was ---> in

# %%
from collections import Counter

word_counts = Counter(words)
vocab = sorted(word_counts.keys())
vocab_size = len(vocab)

print("Vocabulary Size:", vocab_size)
# Out:
# Vocabulary Size: 1477

# %%
most_common_10 = word_counts.most_common(10)
least_common_10 = word_counts.most_common()[-10:]

print("10 Most Frequent Words:", most_common_10)
print("10 Least Frequent Words:", least_common_10)
# Out:
# 10 Most Frequent Words: [('<PAD>', 448), ('the', 283), ('.', 256), ('and', 213), ('to', 185), ('of', 133), ('a', 122), ('her', 99), ('he', 81), ('in', 80)]
# 10 Least Frequent Words: [('ingratiating', 1), ('appealing', 1), ('cost', 1), ('transferred', 1), ('guards', 1), ('difficult', 1), ('advise', 1), ('appeal', 1), ('rumyantsev', 1), ('golit', 1)]

# %%
import torch

if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple Silicon GPU (MPS)")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using NVIDIA GPU (CUDA)")
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using Apple Silicon GPU (MPS)

# %%
stoi = {word: i for i, word in enumerate(vocab)}
itos = {i: word for word, i in stoi.items()}
emb_dim = 32
emb = torch.nn.Embedding(len(stoi), emb_dim)
print(stoi)
print(itos)
# Out:
# {'.': 0, '10': 1, '1805': 2, '7': 3, '<PAD>': 4, 'a': 5, 'abbe': 6, 'abbes': 7, 'ability': 8, 'abnegation': 9, 'about': 10, 'abroad': 11, 'accorded': 12, 'accounts': 13, 'acquaintance': 14, 'act': 15, 'actions': 16, 'active': 17, 'actor': 18, 'actress': 19, 'added': 20, 'addressing': 21, 'adjusting': 22, 'admiring': 23, 'admitting': 24, 'adopted': 25, 'adored': 26, 'advantageous': 27, 'advise': 28, 'affair': 29, 'affectation': 30, 'affected': 31, 'affectionate': 32, 'afraid': 33, 'after': 34, 'again': 35, 'age': 36, 'agitated': 37, 'ah': 38, 'aide': 39, 'alarm': 40, 'alarmed': 41, 'alexanders': 42, 'alike': 43, 'all': 44, 'alliance': 45, 'allowing': 46, 'almost': 47, 'alone': 48, 'also': 49, 'altered': 50, 'altering': 51, 'although': 52, 'always': 53, 'am': 54, 'amazingly': 55, 'ambassadors': 56, 'amiable': 57, 'amiably': 58, 'amid': 59, 'among': 60, 'an': 61, 'anatole': 62, 'and': 63, 'andre': 64, 'andrew': 65, 'anecdote': 66, 'animated': 67, 'animation': 68, 'anna': 69, 'annette': 70, 'annoyance': 71, 'another': 72, 'answer': 73, 'answered': 74, 'anteroom': 75, 'antichrist': 76, 'anxiety': 77, 'anxious': 78, 'any': 79, 'anyone': 80, 'apart': 81, 'appeal': 82, 'appealing': 83, 'appearance': 84, 'appeared': 85, 'appointed': 86, 'appreciate': 87, 'appreciated': 88, 'apprenticeship': 89, 'approached': 90, 'approaching': 91, 'approval': 92, 'are': 93, 'arm': 94, 'armchair': 95, 'arms': 96, 'army': 97, 'around': 98, 'arrange': 99, 'arranged': 100, 'arrival': 101, 'arrivals': 102, 'arrive': 103, 'as': 104, 'ashamed': 105, 'ask': 106, 'asked': 107, 'asking': 108, 'assault': 109, 'assembled': 110, 'assumed': 111, 'astonished': 112, 'at': 113, 'attack': 114, 'attend': 115, 'attended': 116, 'attendez': 117, 'attractive': 118, 'audience': 119, 'aunt': 120, 'austria': 121, 'avenge': 122, 'awaiting': 123, 'away': 124, 'back': 125, 'badge': 126, 'badly': 127, 'bag': 128, 'balance': 129, 'bald': 130, 'ball': 131, 'ballroom': 132, 'bane': 133, 'barbaric': 134, 'bare': 135, 'baron': 136, 'be': 137, 'beamed': 138, 'beaming': 139, 'bear': 140, 'beaucoup': 141, 'beautiful': 142, 'beauty': 143, 'became': 144, 'because': 145, 'become': 146, 'becoming': 147, 'beef': 148, 'been': 149, 'befitting': 150, 'before': 151, 'began': 152, 'begin': 153, 'beginning': 154, 'behalf': 155, 'behave': 156, 'being': 157, 'believe': 158, 'believed': 159, 'belonged': 160, 'belongs': 161, 'below': 162, 'beneath': 163, 'bent': 164, 'beside': 165, 'best': 166, 'betraying': 167, 'better': 168, 'between': 169, 'bezukhov': 170, 'big': 171, 'bigger': 172, 'blood': 173, 'boats': 174, 'body': 175, 'bolkonskaya': 176, 'bolkonski': 177, 'bolkonskis': 178, 'bonaparte': 179, 'bore': 180, 'bored': 181, 'boris': 182, 'born': 183, 'bosom': 184, 'both': 185, 'bowed': 186, 'bows': 187, 'boy': 188, 'breast': 189, 'breeches': 190, 'bright': 191, 'brightened': 192, 'brilliancy': 193, 'brilliant': 194, 'bring': 195, 'broad': 196, 'brother': 197, 'brought': 198, 'brown': 199, 'built': 200, 'bump': 201, 'buonaparte': 202, 'buonapartes': 203, 'burden': 204, 'burn': 205, 'burnt': 206, 'burst': 207, 'but': 208, 'by': 209, 'call': 210, 'called': 211, 'calm': 212, 'came': 213, 'camp': 214, 'can': 215, 'canceled': 216, 'cannot': 217, 'cant': 218, 'cap': 219, 'captured': 220, 'cared': 221, 'carelessness': 222, 'cares': 223, 'careworn': 224, 'carrying': 225, 'case': 226, 'catherines': 227, 'ceaselessly': 228, 'cela': 229, 'celebrity': 230, 'center': 231, 'ceremony': 232, 'certainly': 233, 'chair': 234, 'chairs': 235, 'changed': 236, 'character': 237, 'charmant': 238, 'charmed': 239, 'charming': 240, 'check': 241, 'chief': 242, 'chiefly': 243, 'child': 244, 'children': 245, 'chimerical': 246, 'choice': 247, 'choicest': 248, 'circle': 249, 'civil': 250, 'classic': 251, 'clearcut': 252, 'clearly': 253, 'clever': 254, 'climate': 255, 'clock': 256, 'close': 257, 'closed': 258, 'clouded': 259, 'coarse': 260, 'coat': 261, 'cold': 262, 'color': 263, 'colored': 264, 'come': 265, 'coming': 266, 'commercial': ...
# {0: '.', 1: '10', 2: '1805', 3: '7', 4: '<PAD>', 5: 'a', 6: 'abbe', 7: 'abbes', 8: 'ability', 9: 'abnegation', 10: 'about', 11: 'abroad', 12: 'accorded', 13: 'accounts', 14: 'acquaintance', 15: 'act', 16: 'actions', 17: 'active', 18: 'actor', 19: 'actress', 20: 'added', 21: 'addressing', 22: 'adjusting', 23: 'admiring', 24: 'admitting', 25: 'adopted', 26: 'adored', 27: 'advantageous', 28: 'advise', 29: 'affair', 30: 'affectation', 31: 'affected', 32: 'affectionate', 33: 'afraid', 34: 'after', 35: 'again', 36: 'age', 37: 'agitated', 38: 'ah', 39: 'aide', 40: 'alarm', 41: 'alarmed', 42: 'alexanders', 43: 'alike', 44: 'all', 45: 'alliance', 46: 'allowing', 47: 'almost', 48: 'alone', 49: 'also', 50: 'altered', 51: 'altering', 52: 'although', 53: 'always', 54: 'am', 55: 'amazingly', 56: 'ambassadors', 57: 'amiable', 58: 'amiably', 59: 'amid', 60: 'among', 61: 'an', 62: 'anatole', 63: 'and', 64: 'andre', 65: 'andrew', 66: 'anecdote', 67: 'animated', 68: 'animation', 69: 'anna', 70: 'annette', 71: 'annoyance', 72: 'another', 73: 'answer', 74: 'answered', 75: 'anteroom', 76: 'antichrist', 77: 'anxiety', 78: 'anxious', 79: 'any', 80: 'anyone', 81: 'apart', 82: 'appeal', 83: 'appealing', 84: 'appearance', 85: 'appeared', 86: 'appointed', 87: 'appreciate', 88: 'appreciated', 89: 'apprenticeship', 90: 'approached', 91: 'approaching', 92: 'approval', 93: 'are', 94: 'arm', 95: 'armchair', 96: 'arms', 97: 'army', 98: 'around', 99: 'arrange', 100: 'arranged', 101: 'arrival', 102: 'arrivals', 103: 'arrive', 104: 'as', 105: 'ashamed', 106: 'ask', 107: 'asked', 108: 'asking', 109: 'assault', 110: 'assembled', 111: 'assumed', 112: 'astonished', 113: 'at', 114: 'attack', 115: 'attend', 116: 'attended', 117: 'attendez', 118: 'attractive', 119: 'audience', 120: 'aunt', 121: 'austria', 122: 'avenge', 123: 'awaiting', 124: 'away', 125: 'back', 126: 'badge', 127: 'badly', 128: 'bag', 129: 'balance', 130: 'bald', 131: 'ball', 132: 'ballroom', 133: 'bane', 134: 'barbaric', 135: 'bare', 136: 'baron', 137: 'be', 138: 'beamed', 139: 'beaming', 140: 'bear', 141: 'beaucoup', 142: 'beautiful', 143: 'beauty', 144: 'became', 145: 'because', 146: 'become', 147: 'becoming', 148: 'beef', 149: 'been', 150: 'befitting', 151: 'before', 152: 'began', 153: 'begin', 154: 'beginning', 155: 'behalf', 156: 'behave', 157: 'being', 158: 'believe', 159: 'believed', 160: 'belonged', 161: 'belongs', 162: 'below', 163: 'beneath', 164: 'bent', 165: 'beside', 166: 'best', 167: 'betraying', 168: 'better', 169: 'between', 170: 'bezukhov', 171: 'big', 172: 'bigger', 173: 'blood', 174: 'boats', 175: 'body', 176: 'bolkonskaya', 177: 'bolkonski', 178: 'bolkonskis', 179: 'bonaparte', 180: 'bore', 181: 'bored', 182: 'boris', 183: 'born', 184: 'bosom', 185: 'both', 186: 'bowed', 187: 'bows', 188: 'boy', 189: 'breast', 190: 'breeches', 191: 'bright', 192: 'brightened', 193: 'brilliancy', 194: 'brilliant', 195: 'bring', 196: 'broad', 197: 'brother', 198: 'brought', 199: 'brown', 200: 'built', 201: 'bump', 202: 'buonaparte', 203: 'buonapartes', 204: 'burden', 205: 'burn', 206: 'burnt', 207: 'burst', 208: 'but', 209: 'by', 210: 'call', 211: 'called', 212: 'calm', 213: 'came', 214: 'camp', 215: 'can', 216: 'canceled', 217: 'cannot', 218: 'cant', 219: 'cap', 220: 'captured', 221: 'cared', 222: 'carelessness', 223: 'cares', 224: 'careworn', 225: 'carrying', 226: 'case', 227: 'catherines', 228: 'ceaselessly', 229: 'cela', 230: 'celebrity', 231: 'center', 232: 'ceremony', 233: 'certainly', 234: 'chair', 235: 'chairs', 236: 'changed', 237: 'character', 238: 'charmant', 239: 'charmed', 240: 'charming', 241: 'check', 242: 'chief', 243: 'chiefly', 244: 'child', 245: 'children', 246: 'chimerical', 247: 'choice', 248: 'choicest', 249: 'circle', 250: 'civil', 251: 'classic', 252: 'clearcut', 253: 'clearly', 254: 'clever', 255: 'climate', 256: 'clock', 257: 'close', 258: 'closed', 259: 'clouded', 260: 'coarse', 261: 'coat', 262: 'cold', 263: 'color', 264: 'colored', 265: 'come', 266: 'coming', 267: 'commerc ...

# %%
print(emb.weight.shape)  # should be (vocab_size, emb_dim)
# Out:
# torch.Size([1477, 32])

# %%
X_encoded = [[stoi[word] for word in seq] for seq in X]
Y_encoded = [stoi[word] for word in Y]

# %%
X = torch.tensor(X_encoded, dtype=torch.long).to(device)
Y = torch.tensor(Y_encoded, dtype=torch.long).to(device)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class Nextword(nn.Module):
    def __init__(self, block_size, vocab_size, emb_dim=64, hidden_size=1024):
        super().__init__()
        self.emb = nn.Embedding(vocab_size, emb_dim)
        self.fc1 = nn.Linear(block_size * emb_dim, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, vocab_size)

    def forward(self, x):
        # x: (batch, block_size)
        x = self.emb(x)                           # (batch, block_size, emb_dim)
        x = x.view(x.shape[0], -1)                # flatten
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)                           # logits
        return x

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(
    X, Y, test_size=0.2, random_state=42
)
train_data = torch.utils.data.TensorDataset(X_train, Y_train)
val_data = torch.utils.data.TensorDataset(X_val, Y_val)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=32)

# %%
import time
def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def print_model_summary(model):
    print("Model Summary:")
    for name, module in model.named_modules():
        if len(list(module.children())) == 0:
            params = sum(p.numel() for p in module.parameters())
            print(f"{name:<20} {params:,} parameters")
    print(f"\nTotal trainable parameters: {count_params(model):,}\n")


import torch
import torch.nn as nn
import time

def train_model(model, X, Y, X_val, Y_val, epochs=500, batch_size=1024, lr=1e-3, wd=1e-4, print_every=100):
    """Train the MLP model using AdamW optimizer."""
    model.train()
    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=wd)
    loss_fn = nn.CrossEntropyLoss()

    losses, times, val_losses = [], [], []

    for epoch in range(epochs):
        start = time.time()
        total_loss, n_batches = 0, 0

        # -------- Training --------
        for i in range(0, X.shape[0], batch_size):
            x_batch = X[i:i+batch_size]
            y_batch = Y[i:i+batch_size]

            logits = model(x_batch)
            loss = loss_fn(logits, y_batch)

            opt.zero_grad()
            loss.backward()
            opt.step()

            total_loss += loss.item()
            n_batches += 1

        avg_loss = total_loss / n_batches
        losses.append(avg_loss)
        times.append(time.time() - start)

        # -------- Validation --------
        model.eval()
        val_total_loss, val_batches = 0, 0
        with torch.no_grad():
            for i in range(0, X_val.shape[0], batch_size):
                x_batch = X_val[i:i+batch_size]
                y_batch = Y_val[i:i+batch_size]

                logits = model(x_batch)
                loss = loss_fn(logits, y_batch)
                val_total_loss += loss.item()
                val_batches += 1

        avg_val_loss = val_total_loss / val_batches
        val_losses.append(avg_val_loss)
        model.train()

        # -------- Logging --------
        if epoch % print_every == 0:
            print(f"Epoch {epoch:4d} | Train Loss: {avg_loss:.4f} | Val Loss: {avg_val_loss:.4f} | Time: {times[-1]:.2f}s")

    return losses, times, val_losses

# %%
# Create enhanced model and show before training
block_size = 4
model = Nextword(block_size, len(stoi), emb_dim).to(device)
model = torch.compile(model)

## Model parameters:
print_model_summary(model)
# Out:
# Model Summary:
# _orig_mod.emb        47,264 parameters
# _orig_mod.fc1        132,096 parameters
# _orig_mod.fc2        1,049,600 parameters
# _orig_mod.fc3        1,513,925 parameters
#
# Total trainable parameters: 2,742,885

# %%
import torch

def generate_text(model, stoi, itos, block_size, device, start_context=None, max_len=20):
    """
    Generate a sequence of words from a trained model.

    Args:
        model: Trained PyTorch language model
        stoi: dict, mapping from word → index
        itos: dict, mapping from index → word
        block_size: int, context size expected by the model
        device: torch device ('cuda' or 'cpu')
        start_context: list of str (optional), seed words
        max_len: int, number of words to generate

    Returns:
        str: Generated text sequence
    """

    model.eval()  # evaluation mode (no dropout, etc.)

    # --- Initialize context ---
    if start_context is None:
        context = [stoi['<PAD>']] * block_size  # start with padding
    else:
        # convert words → indices, pad or truncate to block_size
        context = [stoi.get(w, 0) for w in start_context][-block_size:]
        context = [stoi['<PAD>']] * (block_size - len(context)) + context

    generated_words = []

    # --- Generate words one by one ---
    with torch.no_grad():
        for _ in range(max_len):
            x = torch.tensor(context).view(1, -1).to(device)
            y_pred = model(x)  # logits for next word
            ix = torch.distributions.categorical.Categorical(logits=y_pred).sample().item()
            word = itos[ix]

            # stop at end token
            # if word == eos:
            #     break

            generated_words.append(word)

            # slide the context window forward
            context = context[1:] + [ix]

    model.train()  # restore training mode

    return ' '.join(generated_words)

# %%
text = generate_text(model, stoi, itos, block_size=4, device=device)
print(text)
# Out:
# W1103 00:19:48.729000 79650 torch/_inductor/utils.py:1436] [0/0] Not enough SMs to use max_autotune_gemm mode
# louis workbag hastily vocation hatred raised duties arrange ruffle time moscow most lightly gesture secret vienna felt gone just are

# %%
losses, timing , val_losses = train_model(model, X_train, Y_train,X_val,Y_val, epochs=500, batch_size=1024, lr=1e-3, wd=1e-4, print_every=100)
# Out:
# Epoch    0 | Train Loss: 6.6435 | Val Loss: 5.9595 | Time: 0.74s
# Epoch  100 | Train Loss: 0.0964 | Val Loss: 14.9861 | Time: 0.07s
# Epoch  200 | Train Loss: 0.0926 | Val Loss: 15.4392 | Time: 0.07s
# Epoch  300 | Train Loss: 0.0910 | Val Loss: 15.5714 | Time: 0.07s
# Epoch  400 | Train Loss: 0.0901 | Val Loss: 15.7092 | Time: 0.08s

# %%
text = generate_text(model, stoi, itos, block_size=4, device=device, start_context="maid of honor and favorite", max_len=50)
print(text)
# Out:
# <PAD> <PAD> <PAD> <PAD> it is very good of you monsieur pierre to come and anna pavlovna . <PAD> <PAD> <PAD> <PAD> in passing prince vasili wished to obtain this post for at the one of the duc when which of this . <PAD> <PAD> <PAD> <PAD> if you have

# %%
import pandas as pd
df = pd.DataFrame({
    'Epoch': range(1, len(losses) + 1),
    'Train_Loss': losses,
    'Val_Loss': val_losses,
    'Timing': timing
})
df.to_csv('training_log.csv', index=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))

# Loss curves
plt.plot(df['Epoch'], df['Train_Loss'], label='Train Loss', linewidth=2)
plt.plot(df['Epoch'], df['Val_Loss'], label='Validation Loss', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
torch.save(model.state_dict(), 'model_4_32_relu_random.pth')

# %%
from google.colab import drive
drive.mount('/content/drive')

# 1. Define a permanent path in your Google Drive
# This will save it to a folder called "MyModels" in your main Drive
save_path = '/content/drive/MyDrive/MyModels/model_4_32_relu_random.pth'

# 2. Save the model
torch.save(model.state_dict(), save_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       4 # 1. Define a permanent path in your Google Drive
#       5 # This will save it to a folder called "MyModels" in your main Drive
#
# ModuleNotFoundError: No module named 'google.colab'
